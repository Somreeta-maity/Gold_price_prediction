# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/maity/OneDrive/Desktop/xyz/goldprices.csv',parse_dates=['Date'],index_col='Date')
df.head()
# Out:
#             United States(USD)  Europe(EUR)  Japan(JPY)  United Kingdom(GBP)  \
# Date
# 1979-01-31               233.7        144.8     45160.3                117.4
# 1979-02-28               251.3        154.6     50209.1                124.2
# 1979-03-30               240.1        148.0     50274.3                116.2
# 1979-04-30               245.3        152.8     54144.6                118.8
# 1979-05-31               274.6        172.0     61057.1                132.7
#
#             Canada(CAD)  Switzerland(CHF)  India(INR)  China(CNY)  \
# Date
# 1979-01-31        267.1             379.3      1840.8         NaN
# 1979-02-28        295.5             413.6      2011.7         NaN
# 1979-03-30        278.2             406.2      1940.2         NaN
# 1979-04-30        278.5             420.0      2013.1         NaN
# 1979-05-31        321.6             478.0      2253.4         NaN
#
#             Turkey(TRY)  Saudi Arabia(SAR)  Indonesia(IDR)  \
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 511 entries, 1979-01-31 to 2021-07-30
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   United States(USD)         511 non-null    float64
#  1   Europe(EUR)                511 non-null    float64
#  2   Japan(JPY)                 511 non-null    float64
#  3   United Kingdom(GBP)        511 non-null    float64
#  4   Canada(CAD)                511 non-null    float64
#  5   Switzerland(CHF)           511 non-null    float64
#  6   India(INR)                 511 non-null    float64
#  7   China(CNY)                 439 non-null    float64
#  8   Turkey(TRY)                464 non-null    float64
#  9   Saudi Arabia(SAR)          511 non-null    float64
#  10  Indonesia(IDR)             511 non-null    float64
#  11  United Arab Emirates(AED)  511 non-null    float64
#  12  Thailand(THB)              511 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# United States(USD)             0
# Europe(EUR)                    0
# Japan(JPY)                     0
# United Kingdom(GBP)            0
# Canada(CAD)                    0
# Switzerland(CHF)               0
# India(INR)                     0
# China(CNY)                    72
# Turkey(TRY)                   47
# Saudi Arabia(SAR)              0
# Indonesia(IDR)                 0
# United Arab Emirates(AED)      0
# Thailand(THB)                  0
# Vietnam(VND)                 131
# Egypt(EGP)                   119
# South Korean(KRW)              0
# Australia(AUD)                 0
# South Africa(ZAR)              0
# dtype: int64

# %%
df.shape
# Out:
# (511, 18)

# %%
eg=df['Egypt(EGP)'].to_frame()
eg.head()
# Out:
#             Egypt(EGP)
# Date
# 1979-01-31         NaN
# 1979-02-28         NaN
# 1979-03-30         NaN
# 1979-04-30         NaN
# 1979-05-31         NaN

# %%
eg = eg.dropna(axis=0)

# %%
eg.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
eg.rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.columns
# Out:
# Index(['United States(USD)', 'Europe(EUR)', 'Japan(JPY)',
#        'United Kingdom(GBP)', 'Canada(CAD)', 'Switzerland(CHF)', 'India(INR)',
#        'China(CNY)', 'Turkey(TRY)', 'Saudi Arabia(SAR)', 'Indonesia(IDR)',
#        'United Arab Emirates(AED)', 'Thailand(THB)', 'Vietnam(VND)',
#        'Egypt(EGP)', 'South Korean(KRW)', 'Australia(AUD)',
#        'South Africa(ZAR)'],
#       dtype='object')

# %%
df['United States(USD)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Europe(EUR)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Japan(JPY)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['United Kingdom(GBP)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Canada(CAD)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Saudi Arabia(SAR)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Indonesia(IDR)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Turkey(TRY)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['South Africa(ZAR)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.describe()
# Out:
#        United States(USD)  Europe(EUR)     Japan(JPY)  United Kingdom(GBP)  \
# count          511.000000   511.000000     511.000000           511.000000
# mean           693.703914   572.909393   82947.785519           450.144618
# std            473.936956   381.421398   44427.426076           346.745470
# min            233.700000   144.800000   27937.500000           116.200000
# 25%            354.200000   306.950000   43095.750000           218.400000
# 50%            415.100000   364.100000   70455.900000           256.400000
# 75%           1166.650000   929.250000  124847.450000           742.150000
# max           1964.900000  1661.700000  207845.000000          1497.100000
#
#        Canada(CAD)  Switzerland(CHF)     India(INR)    China(CNY)  \
# count   511.000000        511.000000     511.000000    439.000000
# mean    843.504110        826.123288   33124.286301   4883.284510
# std     546.995978        365.533745   36068.222143   3298.648486
# ...

# %%
df.head()
# Out:
#             United States(USD)  Europe(EUR)  Japan(JPY)  United Kingdom(GBP)  \
# Date
# 1979-01-31               233.7        144.8     45160.3                117.4
# 1979-02-28               251.3        154.6     50209.1                124.2
# 1979-03-30               240.1        148.0     50274.3                116.2
# 1979-04-30               245.3        152.8     54144.6                118.8
# 1979-05-31               274.6        172.0     61057.1                132.7
#
#             Canada(CAD)  Switzerland(CHF)  India(INR)  China(CNY)  \
# Date
# 1979-01-31        267.1             379.3      1840.8         NaN
# 1979-02-28        295.5             413.6      2011.7         NaN
# 1979-03-30        278.2             406.2      1940.2         NaN
# 1979-04-30        278.5             420.0      2013.1         NaN
# 1979-05-31        321.6             478.0      2253.4         NaN
#
#             Turkey(TRY)  Saudi Arabia(SAR)  Indonesia(IDR)  \
# Date
# ...
